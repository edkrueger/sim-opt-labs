# %% [markdown]
# # Gas Station Simulator Extension: Requesting Multiple Resources
#
# #### _Edward Krueger, edkrueger@gmail.com_
#
# ## Purpose
#
# Show how to have a process request multiple resources in simpy. This is not a default default behavior, so we'll require a work around.
#
# ## Overview
# We want to add a behavior to Alice's simulator where some cars take up multiple pumps (whether because their cars a very large, because they lack awareness or because they are towing a boat.)
#
# ## Simplifying Assumptions
#
# To highlight the behavior we're looking at we'll make some simplifying assumptions. We'll simplify the simulation so that there are a fixed two pumps, which we'll model and report metrics on directly. We'll also make the assumption that cars are assigned randomly to a pump when they arrive at the gas station. (Perhaps some cars require diesel and some require gasoline and each pump only has one type of fuel.) Finally, we'll assume that when a car block both pumps, it always pumps the fuel from the first one. (Perhaps the large cars are all diesel trucks and they block both pumps, but always fill up with the diesel.) Finally, we'll assume that the utilization metric counts for all blocked pumps whether they are pumping or not.

# %% [markdown]
# # Gas Station Simulator Solution

# %% [markdown]
# ## Setup

# %%
import simpy

import numpy as np

from scipy.stats import expon
from scipy.stats import norm

from contextlib import ExitStack

# %%
class GasPump():
    
    """
    Models a gas pump as a simpy.Resource.
    
    Arguments:
    -----------
    name (str): The name or ID of a pump
    env (simpy.Environment): The simpy environment
    """
    
    def __init__(self, name, env):
        
        self.name = name
                
        self.env = env
        
        self.resource = simpy.PriorityResource(self.env, capacity=1)
        
        self.minutes_utilized = 0
        self.gallons_sold = 0

# %%
class Car():

    """
    Models a car.
    The car's simulation process in the simulation is the method .run().
    
    Arguments:
    -----------
    id (int): A unique id for the car
    gas_required (float): Amount of gallons a car will fill
    lay_time (float): Extra minutes that the car stays at the pump
    gas_pump (GasStation): The gas pumps the car is assigned to.
    env (simpy.Environment): The simpy environment
    
    """
    
    def __init__(
        self,
        id,
        gas_required,
        lay_time,
        gas_pumps,
        env
    ):
        
        self.id = id
        self.gas_required = gas_required
        self.lay_time = lay_time
        self.gas_pumps = gas_pumps
        self.env = env
        
        self.wait_time = np.inf
        self.finished = False
        
        self.pump_names = " ".join([gas_pump.name for gas_pump in gas_pumps])
        
        self.action = self.env.process(self.run())
        
    def run(self):
        
        queue_time = self.env.now
        
        print(f'Car {self.id} arrives at {round(queue_time, 2)} minutes')
        
                
        with ExitStack() as stack:
            
            reqs = [
                stack.enter_context(
                    res.resource.request(
                        priority=1
                    )
                ) for res in self.gas_pumps
            ]
            
            yield self.env.all_of(reqs)
            
            pump_start_time = self.env.now
            
            print(f'Car {self.id} begins utilizing pumps {self.pump_names} at {round(pump_start_time, 2)} minutes')

            pump_time = self.gas_required / PUMP_RATE
            utilization = max(pump_time, self.lay_time)
            
            yield self.env.timeout(utilization)
            
            pump_end_time = self.env.now
            
            print(f'Car {self.id} end utilizing pumps {self.pump_names} at {round(pump_end_time, 2)} minutes')
            
            self.finished = True
            
            self.wait_time = pump_start_time - queue_time
            
            # add the utilization to all pumps
            for gas_pump in self.gas_pumps:
                gas_pump.minutes_utilized += utilization
                
            # add the gas to only the first pump
            self.gas_pumps[0].gallons_sold += self.gas_required

# %%
class ClosureEvent():
    
    def __init__(
        self,
        start_time,
        duration,
        pump,
        env
    ):
        
        self.start_time = start_time
        self.duration = duration
        self.pump = pump
        
        self.env = env
        
        self.action = self.env.process(self.run())
        
    def run(self):
        
        with self.pump.resource.request(priority=0) as req:
            
            yield req
            
            print(f'Closure event starts at pump {self.pump.name} starts at {self.env.now}')
            
            remaining_duration = max([
                0,
                self.duration - (self.env.now - self.start_time)
            ])
            
            yield self.env.timeout(remaining_duration)
            
            print(print(f'Closure event ends at pump {self.pump.name} starts at {self.env.now}'))

# %%
class GlobalClosureEvent():
    
    def __init__(
        self,
        start_time,
        duration,
        env
    ):
        
        self.start_time = start_time
        self.duration = duration
        
        self.env = env
        
        self.action = self.env.process(self.run())
    
    def run(self):
        
        for pump in pumps:

            ClosureEvent(
                start_time=self.start_time,
                duration=self.duration,
                pump=pump,
                env=self.env
            )
            
        yield env.timeout(0)

# %%
def closure_scheduler(env):
    
    yield env.timeout(50)
    
    GlobalClosureEvent(
        start_time=50,
        duration=30,
        env=env
    )

# %%
def scheduler(env):
    
    """
    Controls the arrival of cars at the gas station.
    
    Arguments:
    -----------
    env (simpy.Environment): The simpy environment
    """
    
    id = 0
    
    while True:
        
        waiting_time = expon.rvs(loc=0, scale=EXPECTED_WAIT)
        
        std_norm = norm.rvs()
        gas_required = std_norm * GAS_REQUIRED_STD + GAS_REQUIRED_MEAN
        gas_required = max([0, gas_required])
        
        lay_time = expon.rvs(loc=0, scale=EXPECTED_LAY_TIME)
        
        yield env.timeout(waiting_time)
        
        gas_pumps = np.random.choice(
            a = [
                [np.random.choice(pumps)],
                pumps
            ],
            p = [
                1- PROP_LARGE_CARS,
                PROP_LARGE_CARS,
            ]
        )
        
        CARS.append(
            Car(
                id=id,
                gas_required=gas_required,
                lay_time=lay_time,
                gas_pumps=gas_pumps,
                env=env
            )
        )
        
        id += 1

# %% [markdown]
# ## Input parameters and run the simulation

# %%
EXPECTED_WAIT = 2 # in minutes

GAS_REQUIRED_MEAN = 15 # in gallons
GAS_REQUIRED_STD = 5 # in gallons

PUMP_RATE = 10 # in gallons per minute

EXPECTED_LAY_TIME = 5 # in minutes

PROP_LARGE_CARS = .15 # in [0,1]

sim_time = 24 * 60 # in minutes

# %% [markdown]
# ## Wrap up the simulation and metrics

# %%
env = simpy.Environment()
CARS = []

pump_1 = GasPump("1", env)
pump_2 = GasPump("2", env)
pumps = [pump_1, pump_2]

env.process(scheduler(env))
env.process(closure_scheduler(env))

env.run(until=sim_time)
# Out:
# Car 0 arrives at 0.21 minutes
# Car 0 begins utilizing pumps 2 at 0.21 minutes
# Car 1 arrives at 0.36 minutes
# Car 2 arrives at 0.7 minutes
# Car 0 end utilizing pumps 2 at 3.86 minutes
# Car 1 begins utilizing pumps 2 at 3.86 minutes
# Car 3 arrives at 5.98 minutes
# Car 3 begins utilizing pumps 1 at 5.98 minutes
# Car 4 arrives at 6.38 minutes
# Car 5 arrives at 7.21 minutes
# Car 6 arrives at 7.29 minutes
# Car 7 arrives at 8.03 minutes
# Car 8 arrives at 9.33 minutes
# Car 9 arrives at 9.92 minutes
# Car 10 arrives at 10.24 minutes
# Car 1 end utilizing pumps 2 at 10.73 minutes
# Car 2 begins utilizing pumps 2 at 10.73 minutes
# Car 11 arrives at 12.14 minutes
# Car 12 arrives at 12.98 minutes
# Car 13 arrives at 13.25 minutes
# Car 2 end utilizing pumps 2 at 14.27 minutes
# Car 14 arrives at 16.31 minutes
# Car 3 end utilizing pumps 1 at 17.92 minutes
# Car 4 begins utilizing pumps 1 2 at 17.92 minutes
# Car 15 arrives at 19.71 minutes
# Car 16 arrives at 29.82 minutes
# Car 17 arrives at 29.88 minutes
# Car 18 arrives at 30.13 minutes
# Car 4 end utilizing pumps 1 2 at 33.36 minutes
# Car 5 begins utilizing pumps 2 at 33.36 minutes
# Car 19 arrives at 33.48 minutes
# Car 20 arrives at 36.12 minutes
# Car 21 arrives at 36.65 minutes
# Car 5 end utilizing pumps 2 at 37.5 minutes
# Car 6 begins utilizing pumps 1 2 at 37.5 minutes
# Car 22 arrives at 37.82 minutes
# Car 6 end utilizing pumps 1 2 at 38.89 minutes
# Car 7 begins utilizing pumps 2 at 38.89 minutes
# Car 8 begins utilizing pumps 1 at 38.89 minutes
# Car 23 arrives at 40.33 minutes
# Car 8 end utilizing pumps 1 at 40.69 minutes
# Car 9 begins utilizing pumps 1 at 40.69 minutes
# Car 24 arrives at 41.6 minutes
# Car 9 end utilizing pumps 1 at 42.92 minutes
# Car 12 begins utilizing pumps 1 at 42.92 minutes
# Car 12 end utilizing pumps 1 at 43.69 minutes
# Car 13 begins utilizing pumps 1 at 43.69 minutes
# Car 25 arrives at 44.07 minutes
# Car 26 arrives at 45.24 minutes
# Car 13 end utilizing pumps 1 at 46.11 minutes
# Car 17 begins utilizing pumps 1 at 46.11 minutes
# Car 17 end utilizing pumps 1 at 47.72 minutes
# Car 21 begins utilizing pumps 1 at 47.72 minutes
# Car 27 arrives at 50.06 minutes
# Car 21 end utilizing pumps 1 at 50.23 minutes
# Closure event starts at pump 1 starts at 50.23002376795673
# Car 7 end utilizing pumps 2 at 50.35 minutes
# Closure event starts at pump 2 starts at 50.348844811662275
# Car 28 arrives at 54.72 minutes
# Car 29 arrives at 55.03 minutes
# Car 30 arrives at 57.57 minutes
# Car 31 arrives at 58.22 minutes
# Car 32 arrives at 58.62 minutes
# Car 33 arrives at 58.71 minutes
# Car 34 arrives at 59.29 minutes
# Car 35 arrives at 59.87 minutes
# Car 36 arrives at 62.09 minutes
# Car 37 arrives at 62.5 minutes
# Car 38 arrives at 63.23 minutes
# Car 39 arrives at 64.73 minutes
# Car 40 arrives at 65.59 minutes
# Car 41 arrives at 66.33 minutes
# Car 42 arrives at 70.51 minutes
# Car 43 arrives at 72.57 minutes
# Car 44 arrives at 74.66 minutes
# Closure event ends at pump 1 starts at 80.0
# None
# Closure event ends at pump 2 starts at 80.0
# None
# Car 23 begins utilizing pumps 1 at 80.0 minutes
# Car 95 arrives at 195.81 minutes
# Car 51 end utilizing pumps 2 at 196.05 minutes
# Car 58 begins utilizing pumps 2 at 196.05 minutes
# Car 96 arrives at 196.36 minutes
# Car 97 arrives at 196.6 minutes
# Car 58 end utilizing pumps 2 at 198.38 minutes
# Car 60 begins utilizing pumps 2 at 198.38 minutes
# Car 52 end utilizing pumps 1 at 201.43 minutes
# Car 53 begins utilizing pumps 1 at 201.43 minutes
# Car 60 end utilizing pumps 2 at 201.99 minutes
# Car 98 arrives at 203.32 minutes
# Car 99 arrives at 203.46 minutes
# Car 100 arrives at 205.31 minutes
# Car 53 end utilizing pumps 1 at 205.69 minutes
# Car 54 begins utilizing pumps 1 at 205.69 minutes
# Car 101 arrives at 208.15 minutes
# Car 102 arrives at 209.53 minutes
# Car 54 end utilizing pumps 1 at 209.88 minutes
# Car 55 begins utilizing pumps 1 at 209.88 minutes
# Car 103 arrives at 210.41 minutes
# Car 104 arrives at 210.87 minutes
# Car 105 arrives at 211.26 minutes
# Car 106 arrives at 212.4 minutes
# Car 55 end utilizing pumps 1 at 213.43 minutes
# Car 56 begins utilizing pumps 1 at 213.43 minutes
# Car 107 arrives at 214.73 minutes
# Car 108 arrives at 215.58 minutes
# Car 109 arrives at 218.04 minutes
# Car 110 arrives at 218.09 minutes
# Car 56 end utilizing pumps 1 at 219.66 minutes
# Car 57 begins utilizing pumps 1 at 219.66 minutes
# Car 111 arrives at 221.7 minutes
# Car 112 arrives at 222.63 minutes
# Car 57 end utilizing pumps 1 at 224.59 minutes
# Car 59 begins utilizing pumps 1 at 224.59 minutes
# Car 113 arrives at 225.0 minutes
# Car 114 arrives at 226.81 minutes
# Car 59 end utilizing pumps 1 at 227.44 minutes
# Car 61 begins utilizing pumps 1 at 227.44 minutes
# Car 115 arrives at 228.1 minutes
# Car 116 arrives at 230.24 minutes
# Car 117 arrives at 231.1 minutes
# Car 61 end utilizing pumps 1 at 231.84 minutes
# Car 62 begins utilizing pumps 1 2 at 231.84 minutes
# Car 118 arrives at 231.91 minutes
# Car 119 arrives at 233.52 minutes
# Car 120 arrives at 236.11 minutes
# Car 121 arrives at 236.92 minutes
# Car 122 arrives at 237.78 minutes
# Car 62 end utilizing pumps 1 2 at 239.63 minutes
# Car 63 begins utilizing pumps 2 at 239.63 minutes
# Car 123 arrives at 240.71 minutes
# Car 63 end utilizing pumps 2 at 241.27 minutes
# Car 64 begins utilizing pumps 1 2 at 241.27 minutes
# Car 64 end utilizing pumps 1 2 at 242.47 minutes
# Car 65 begins utilizing pumps 2 at 242.47 minutes
# Car 66 begins utilizing pumps 1 at 242.47 minutes
# Car 124 arrives at 245.55 minutes
# Car 125 arrives at 245.67 minutes
# Car 65 end utilizing pumps 2 at 246.75 minutes
# Car 126 arrives at 246.81 minutes
# Car 66 end utilizing pumps 1 at 248.12 minutes
# Car 67 begins utilizing pumps 1 2 at 248.12 minutes
# Car 127 arrives at 248.68 minutes
# Car 128 arrives at 250.62 minutes
# Car 129 arrives at 250.77 minutes
# Car 346 begins utilizing pumps 1 at 1271.54 minutes
# Car 346 end utilizing pumps 1 at 1272.77 minutes
# Car 347 begins utilizing pumps 1 at 1272.77 minutes
# Car 585 arrives at 1272.84 minutes
# Car 586 arrives at 1272.98 minutes
# Car 587 arrives at 1273.41 minutes
# Car 588 arrives at 1273.98 minutes
# Car 589 arrives at 1278.51 minutes
# Car 347 end utilizing pumps 1 at 1279.63 minutes
# Car 348 begins utilizing pumps 1 at 1279.63 minutes
# Car 590 arrives at 1280.95 minutes
# Car 591 arrives at 1281.51 minutes
# Car 592 arrives at 1281.84 minutes
# Car 593 arrives at 1281.91 minutes
# Car 594 arrives at 1282.36 minutes
# Car 595 arrives at 1282.76 minutes
# Car 596 arrives at 1284.42 minutes
# Car 348 end utilizing pumps 1 at 1286.03 minutes
# Car 349 begins utilizing pumps 1 2 at 1286.03 minutes
# Car 597 arrives at 1287.5 minutes
# Car 349 end utilizing pumps 1 2 at 1289.5 minutes
# Car 350 begins utilizing pumps 1 at 1289.5 minutes
# Car 598 arrives at 1290.51 minutes
# Car 599 arrives at 1292.68 minutes
# Car 350 end utilizing pumps 1 at 1294.81 minutes
# Car 351 begins utilizing pumps 1 at 1294.81 minutes
# Car 600 arrives at 1294.88 minutes
# Car 601 arrives at 1295.71 minutes
# Car 602 arrives at 1296.99 minutes
# Car 603 arrives at 1297.42 minutes
# Car 351 end utilizing pumps 1 at 1297.58 minutes
# Car 352 begins utilizing pumps 1 at 1297.58 minutes
# Car 604 arrives at 1297.8 minutes
# Car 352 end utilizing pumps 1 at 1300.31 minutes
# Car 353 begins utilizing pumps 1 at 1300.31 minutes
# Car 605 arrives at 1301.7 minutes
# Car 606 arrives at 1303.04 minutes
# Car 607 arrives at 1303.53 minutes
# Car 608 arrives at 1306.08 minutes
# Car 609 arrives at 1306.65 minutes
# Car 353 end utilizing pumps 1 at 1310.77 minutes
# Car 354 begins utilizing pumps 1 2 at 1310.77 minutes
# Car 610 arrives at 1310.86 minutes
# Car 611 arrives at 1311.11 minutes
# Car 612 arrives at 1311.33 minutes
# Car 613 arrives at 1312.64 minutes
# Car 614 arrives at 1312.81 minutes
# Car 615 arrives at 1314.51 minutes
# Car 616 arrives at 1314.86 minutes
# Car 617 arrives at 1316.18 minutes
# Car 618 arrives at 1317.26 minutes
# Car 619 arrives at 1318.7 minutes
# Car 620 arrives at 1319.54 minutes
# Car 621 arrives at 1325.04 minutes
# Car 622 arrives at 1325.3 minutes
# Car 623 arrives at 1325.54 minutes
# Car 624 arrives at 1326.24 minutes
# Car 625 arrives at 1327.61 minutes
# Car 626 arrives at 1328.04 minutes
# Car 627 arrives at 1328.62 minutes
# Car 628 arrives at 1328.84 minutes
# Car 354 end utilizing pumps 1 2 at 1329.79 minutes
# Car 355 begins utilizing pumps 2 at 1329.79 minutes
# Car 629 arrives at 1331.64 minutes
# Car 630 arrives at 1332.79 minutes
# Car 631 arrives at 1333.25 minutes
# Car 632 arrives at 1339.22 minutes
# Car 633 arrives at 1341.5 minutes
# Car 663 arrives at 1405.27 minutes
# Car 370 end utilizing pumps 1 at 1406.23 minutes
# Car 372 begins utilizing pumps 1 2 at 1406.23 minutes
# Car 664 arrives at 1406.3 minutes
# Car 372 end utilizing pumps 1 2 at 1408.78 minutes
# Car 373 begins utilizing pumps 2 at 1408.78 minutes
# Car 375 begins utilizing pumps 1 at 1408.78 minutes
# Car 665 arrives at 1409.32 minutes
# Car 373 end utilizing pumps 2 at 1412.76 minutes
# Car 374 begins utilizing pumps 2 at 1412.76 minutes
# Car 666 arrives at 1414.02 minutes
# Car 667 arrives at 1415.06 minutes
# Car 374 end utilizing pumps 2 at 1417.95 minutes
# Car 375 end utilizing pumps 1 at 1418.07 minutes
# Car 376 begins utilizing pumps 1 at 1418.07 minutes
# Car 668 arrives at 1419.1 minutes
# Car 669 arrives at 1419.81 minutes
# Car 670 arrives at 1421.17 minutes
# Car 376 end utilizing pumps 1 at 1423.37 minutes
# Car 377 begins utilizing pumps 1 at 1423.37 minutes
# Car 377 end utilizing pumps 1 at 1423.91 minutes
# Car 378 begins utilizing pumps 1 2 at 1423.91 minutes
# Car 671 arrives at 1425.13 minutes
# Car 672 arrives at 1426.24 minutes
# Car 378 end utilizing pumps 1 2 at 1426.5 minutes
# Car 380 begins utilizing pumps 2 at 1426.5 minutes
# Car 379 begins utilizing pumps 1 at 1426.5 minutes
# Car 673 arrives at 1426.7 minutes
# Car 674 arrives at 1427.84 minutes
# Car 380 end utilizing pumps 2 at 1428.19 minutes
# Car 382 begins utilizing pumps 2 at 1428.19 minutes
# Car 675 arrives at 1429.87 minutes
# Car 379 end utilizing pumps 1 at 1430.47 minutes
# Car 381 begins utilizing pumps 1 at 1430.47 minutes
# Car 676 arrives at 1430.77 minutes
# Car 382 end utilizing pumps 2 at 1431.93 minutes
# Car 385 begins utilizing pumps 2 at 1431.93 minutes
# Car 385 end utilizing pumps 2 at 1434.04 minutes
# Car 386 begins utilizing pumps 2 at 1434.04 minutes
# Car 677 arrives at 1434.98 minutes
# Car 386 end utilizing pumps 2 at 1435.88 minutes
# Car 387 begins utilizing pumps 2 at 1435.88 minutes
# Car 678 arrives at 1437.98 minutes
# Car 381 end utilizing pumps 1 at 1439.49 minutes
# Car 383 begins utilizing pumps 1 at 1439.49 minutes

# %%
avg_wait_time = np.array([car.wait_time for car in CARS if car.finished]).mean()
total_gallons_sold = sum([pump.gallons_sold for pump in pumps])

for pump in pumps:
    utilization = pump.minutes_utilized / sim_time * len(pumps) 
    print(f'Utilization for pump {pump.name}: {utilization}')
    
for pump in pumps:
    gallons = pump.gallons_sold
    print(f'Gallons sold at pump {pump.name}: {gallons}')
    


print(f'Average wait time (minutes): {avg_wait_time}')
print(f'Total Gallons Sold: {total_gallons_sold}')
# Out:
# Utilization for pump 1: 1.7328734117308335
# Utilization for pump 2: 1.3780089968571283
# Gallons sold at pump 1: 3484.2239240663566
# Gallons sold at pump 2: 2442.3457501210028
# Average wait time (minutes): 325.0779479214482
# Total Gallons Sold: 5926.56967418736
