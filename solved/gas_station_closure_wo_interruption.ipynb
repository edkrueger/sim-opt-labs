# %% [markdown]
# # Gas Station Simulator Extension: Requesting Multiple Resources
#
# #### _Edward Krueger, edkrueger@gmail.com_
#
# ## Purpose
#
# Show how to have a process request multiple resources in simpy. This is not a default default behavior, so we'll require a work around.
#
# ## Overview
# We want to add a behavior to Alice's simulator where some cars take up multiple pumps (whether because their cars a very large, because they lack awareness or because they are towing a boat.)
#
# ## Simplifying Assumptions
#
# To highlight the behavior we're looking at we'll make some simplifying assumptions. We'll simplify the simulation so that there are a fixed two pumps, which we'll model and report metrics on directly. We'll also make the assumption that cars are assigned randomly to a pump when they arrive at the gas station. (Perhaps some cars require diesel and some require gasoline and each pump only has one type of fuel.) Finally, we'll assume that when a car block both pumps, it always pumps the fuel from the first one. (Perhaps the large cars are all diesel trucks and they block both pumps, but always fill up with the diesel.) Finally, we'll assume that the utilization metric counts for all blocked pumps whether they are pumping or not.

# %% [markdown]
# # Gas Station Simulator Solution

# %% [markdown]
# ## Setup

# %%
import simpy

import numpy as np

from scipy.stats import expon
from scipy.stats import norm

from contextlib import ExitStack

# %%
class GasPump():
    
    """
    Models a gas pump as a simpy.Resource.
    
    Arguments:
    -----------
    name (str): The name or ID of a pump
    env (simpy.Environment): The simpy environment
    """
    
    def __init__(self, name, env):
        
        self.name = name
                
        self.env = env
        
        self.resource = simpy.PriorityResource(self.env, capacity=1)
        
        self.minutes_utilized = 0
        self.gallons_sold = 0

# %%
class Car():

    """
    Models a car.
    The car's simulation process in the simulation is the method .run().
    
    Arguments:
    -----------
    id (int): A unique id for the car
    gas_required (float): Amount of gallons a car will fill
    lay_time (float): Extra minutes that the car stays at the pump
    gas_pump (GasStation): The gas pumps the car is assigned to.
    env (simpy.Environment): The simpy environment
    
    """
    
    def __init__(
        self,
        id,
        gas_required,
        lay_time,
        gas_pumps,
        env
    ):
        
        self.id = id
        self.gas_required = gas_required
        self.lay_time = lay_time
        self.gas_pumps = gas_pumps
        self.env = env
        
        self.wait_time = np.inf
        self.finished = False
        
        self.pump_names = " ".join([gas_pump.name for gas_pump in gas_pumps])
        
        self.action = self.env.process(self.run())
        
    def run(self):
        
        queue_time = self.env.now
        
        print(f'Car {self.id} arrives at {round(queue_time, 2)} minutes')
        
                
        with ExitStack() as stack:
            
            reqs = [
                stack.enter_context(
                    res.resource.request(
                        priority=1
                    )
                ) for res in self.gas_pumps
            ]
            
            yield self.env.all_of(reqs)
            
            pump_start_time = self.env.now
            
            print(f'Car {self.id} begins utilizing pumps {self.pump_names} at {round(pump_start_time, 2)} minutes')

            pump_time = self.gas_required / PUMP_RATE
            utilization = max(pump_time, self.lay_time)
            
            yield self.env.timeout(utilization)
            
            pump_end_time = self.env.now
            
            print(f'Car {self.id} end utilizing pumps {self.pump_names} at {round(pump_end_time, 2)} minutes')
            
            self.finished = True
            
            self.wait_time = pump_start_time - queue_time
            
            # add the utilization to all pumps
            for gas_pump in self.gas_pumps:
                gas_pump.minutes_utilized += utilization
                
            # add the gas to only the first pump
            self.gas_pumps[0].gallons_sold += self.gas_required

# %%
class ClosureEvent():
    
    def __init__(
        self,
        start_time,
        duration,
        pump,
        env
    ):
        
        self.start_time = start_time
        self.duration = duration
        self.pump = pump
        
        self.env = env
        
        self.action = self.env.process(self.run())
        
    def run(self):
        
        with self.pump.resource.request(priority=0) as req:
            
            yield req
            
            print(f'Closure event starts at pump {self.pump.name} starts at {self.env.now}')
            
            remaining_duration = max([
                0,
                self.duration - (self.env.now - self.start_time)
            ])
            
            yield self.env.timeout(remaining_duration)
            
            print(print(f'Closure event ends at pump {self.pump.name} starts at {self.env.now}'))

# %%
class GlobalClosureEvent():
    
    def __init__(
        self,
        start_time,
        duration,
        env
    ):
        
        self.start_time = start_time
        self.duration = duration
        
        self.env = env
        
        self.action = self.env.process(self.run())
    
    def run(self):
        
        for pump in pumps:

            ClosureEvent(
                start_time=self.start_time,
                duration=self.duration,
                pump=pump,
                env=self.env
            )
            
        yield env.timeout(0)

# %%
def closure_scheduler(env):
    
    yield env.timeout(50)
    
    GlobalClosureEvent(
        start_time=50,
        duration=30,
        env=env
    )

# %%
def scheduler(env):
    
    """
    Controls the arrival of cars at the gas station.
    
    Arguments:
    -----------
    env (simpy.Environment): The simpy environment
    """
    
    id = 0
    
    while True:
        
        waiting_time = expon.rvs(loc=0, scale=EXPECTED_WAIT)
        
        std_norm = norm.rvs()
        gas_required = std_norm * GAS_REQUIRED_STD + GAS_REQUIRED_MEAN
        gas_required = max([0, gas_required])
        
        lay_time = expon.rvs(loc=0, scale=EXPECTED_LAY_TIME)
        
        yield env.timeout(waiting_time)
        
        gas_pumps = np.random.choice(
            a = [
                [np.random.choice(pumps)],
                pumps
            ],
            p = [
                1- PROP_LARGE_CARS,
                PROP_LARGE_CARS,
            ]
        )
        
        CARS.append(
            Car(
                id=id,
                gas_required=gas_required,
                lay_time=lay_time,
                gas_pumps=gas_pumps,
                env=env
            )
        )
        
        id += 1

# %% [markdown]
# ## Input parameters and run the simulation

# %%
EXPECTED_WAIT = 2 # in minutes

GAS_REQUIRED_MEAN = 15 # in gallons
GAS_REQUIRED_STD = 5 # in gallons

PUMP_RATE = 10 # in gallons per minute

EXPECTED_LAY_TIME = 5 # in minutes

PROP_LARGE_CARS = .15 # in [0,1]

sim_time = 24 * 60 # in minutes

# %% [markdown]
# ## Wrap up the simulation and metrics

# %%
env = simpy.Environment()
CARS = []

pump_1 = GasPump("1", env)
pump_2 = GasPump("2", env)
pumps = [pump_1, pump_2]

env.process(scheduler(env))
env.process(closure_scheduler(env))

env.run(until=sim_time)
# Out:
# Car 0 arrives at 0.58 minutes
# Car 0 begins utilizing pumps 2 at 0.58 minutes
# Car 1 arrives at 2.66 minutes
# Car 1 begins utilizing pumps 1 at 2.66 minutes
# Car 0 end utilizing pumps 2 at 3.2 minutes
# Car 1 end utilizing pumps 1 at 4.36 minutes
# Car 2 arrives at 6.34 minutes
# Car 2 begins utilizing pumps 2 at 6.34 minutes
# Car 2 end utilizing pumps 2 at 8.25 minutes
# Car 3 arrives at 8.57 minutes
# Car 3 begins utilizing pumps 1 at 8.57 minutes
# Car 3 end utilizing pumps 1 at 10.32 minutes
# Car 4 arrives at 10.42 minutes
# Car 4 begins utilizing pumps 1 at 10.42 minutes
# Car 5 arrives at 12.08 minutes
# Car 6 arrives at 12.78 minutes
# Car 6 begins utilizing pumps 2 at 12.78 minutes
# Car 7 arrives at 12.97 minutes
# Car 6 end utilizing pumps 2 at 14.53 minutes
# Car 7 begins utilizing pumps 2 at 14.53 minutes
# Car 8 arrives at 15.89 minutes
# Car 7 end utilizing pumps 2 at 16.03 minutes
# Car 9 arrives at 17.68 minutes
# Car 10 arrives at 17.89 minutes
# Car 11 arrives at 19.08 minutes
# Car 4 end utilizing pumps 1 at 21.3 minutes
# Car 5 begins utilizing pumps 1 at 21.3 minutes
# Car 12 arrives at 22.58 minutes
# Car 5 end utilizing pumps 1 at 22.87 minutes
# Car 8 begins utilizing pumps 1 at 22.87 minutes
# Car 13 arrives at 23.52 minutes
# Car 14 arrives at 24.19 minutes
# Car 8 end utilizing pumps 1 at 26.69 minutes
# Car 9 begins utilizing pumps 1 2 at 26.69 minutes
# Car 9 end utilizing pumps 1 2 at 29.82 minutes
# Car 10 begins utilizing pumps 1 2 at 29.82 minutes
# Car 10 end utilizing pumps 1 2 at 32.04 minutes
# Car 11 begins utilizing pumps 2 at 32.04 minutes
# Car 12 begins utilizing pumps 1 at 32.04 minutes
# Car 15 arrives at 32.35 minutes
# Car 16 arrives at 34.22 minutes
# Car 12 end utilizing pumps 1 at 39.03 minutes
# Car 17 arrives at 41.13 minutes
# Car 18 arrives at 42.9 minutes
# Car 11 end utilizing pumps 2 at 42.97 minutes
# Car 13 begins utilizing pumps 2 at 42.97 minutes
# Car 19 arrives at 43.07 minutes
# Car 20 arrives at 44.74 minutes
# Car 21 arrives at 45.08 minutes
# Car 22 arrives at 45.52 minutes
# Car 23 arrives at 45.73 minutes
# Car 13 end utilizing pumps 2 at 45.91 minutes
# Car 14 begins utilizing pumps 1 2 at 45.91 minutes
# Car 24 arrives at 46.38 minutes
# Car 14 end utilizing pumps 1 2 at 47.05 minutes
# Car 15 begins utilizing pumps 1 at 47.05 minutes
# Car 25 arrives at 47.87 minutes
# Car 15 end utilizing pumps 1 at 48.29 minutes
# Car 16 begins utilizing pumps 1 2 at 48.29 minutes
# Car 26 arrives at 49.04 minutes
# Car 27 arrives at 49.41 minutes
# Car 16 end utilizing pumps 1 2 at 51.6 minutes
# Closure event starts at pump 2 starts at 51.60348955396748
# Closure event starts at pump 1 starts at 51.60348955396748
# Car 28 arrives at 58.63 minutes
# Car 29 arrives at 59.2 minutes
# Car 30 arrives at 59.6 minutes
# Car 31 arrives at 60.02 minutes
# Car 32 arrives at 61.59 minutes
# Car 33 arrives at 61.91 minutes
# Car 34 arrives at 65.65 minutes
# Car 35 arrives at 72.55 minutes
# Car 36 arrives at 75.17 minutes
# Closure event ends at pump 2 starts at 80.0
# None
# Closure event ends at pump 1 starts at 80.0
# None
# Car 17 begins utilizing pumps 1 2 at 80.0 minutes
# Car 37 arrives at 80.32 minutes
# Car 158 end utilizing pumps 1 at 561.62 minutes
# Car 159 begins utilizing pumps 1 2 at 561.62 minutes
# Car 275 arrives at 562.17 minutes
# Car 276 arrives at 562.69 minutes
# Car 277 arrives at 564.26 minutes
# Car 159 end utilizing pumps 1 2 at 565.79 minutes
# Car 161 begins utilizing pumps 2 at 565.79 minutes
# Car 160 begins utilizing pumps 1 at 565.79 minutes
# Car 161 end utilizing pumps 2 at 566.67 minutes
# Car 160 end utilizing pumps 1 at 566.95 minutes
# Car 162 begins utilizing pumps 1 2 at 566.95 minutes
# Car 162 end utilizing pumps 1 2 at 569.26 minutes
# Car 163 begins utilizing pumps 2 at 569.26 minutes
# Car 278 arrives at 569.89 minutes
# Car 163 end utilizing pumps 2 at 573.43 minutes
# Car 164 begins utilizing pumps 1 2 at 573.43 minutes
# Car 279 arrives at 576.37 minutes
# Car 280 arrives at 577.11 minutes
# Car 281 arrives at 578.61 minutes
# Car 282 arrives at 580.84 minutes
# Car 283 arrives at 581.44 minutes
# Car 284 arrives at 581.54 minutes
# Car 285 arrives at 581.88 minutes
# Car 286 arrives at 584.21 minutes
# Car 287 arrives at 584.42 minutes
# Car 288 arrives at 584.45 minutes
# Car 289 arrives at 586.64 minutes
# Car 290 arrives at 586.71 minutes
# Car 291 arrives at 586.88 minutes
# Car 292 arrives at 587.22 minutes
# Car 293 arrives at 587.93 minutes
# Car 294 arrives at 589.62 minutes
# Car 295 arrives at 594.44 minutes
# Car 296 arrives at 594.74 minutes
# Car 164 end utilizing pumps 1 2 at 595.22 minutes
# Car 165 begins utilizing pumps 1 2 at 595.22 minutes
# Car 297 arrives at 595.58 minutes
# Car 165 end utilizing pumps 1 2 at 596.54 minutes
# Car 166 begins utilizing pumps 2 at 596.54 minutes
# Car 298 arrives at 597.5 minutes
# Car 299 arrives at 597.97 minutes
# Car 166 end utilizing pumps 2 at 600.2 minutes
# Car 167 begins utilizing pumps 1 2 at 600.2 minutes
# Car 300 arrives at 601.09 minutes
# Car 301 arrives at 602.23 minutes
# Car 302 arrives at 604.08 minutes
# Car 303 arrives at 604.2 minutes
# Car 167 end utilizing pumps 1 2 at 605.61 minutes
# Car 169 begins utilizing pumps 2 at 605.61 minutes
# Car 168 begins utilizing pumps 1 at 605.61 minutes
# Car 304 arrives at 605.78 minutes
# Car 168 end utilizing pumps 1 at 607.64 minutes
# Car 173 begins utilizing pumps 1 at 607.64 minutes
# Car 169 end utilizing pumps 2 at 607.87 minutes
# Car 170 begins utilizing pumps 2 at 607.87 minutes
# Car 305 arrives at 608.59 minutes
# Car 306 arrives at 610.09 minutes
# Car 170 end utilizing pumps 2 at 613.86 minutes
# Car 171 begins utilizing pumps 2 at 613.86 minutes
# Car 307 arrives at 614.56 minutes
# Car 308 arrives at 616.16 minutes
# Car 309 arrives at 616.63 minutes
# Car 310 arrives at 617.31 minutes
# Car 311 arrives at 622.35 minutes
# Car 171 end utilizing pumps 2 at 622.68 minutes
# Car 172 begins utilizing pumps 2 at 622.68 minutes
# Car 384 arrives at 778.4 minutes
# Car 203 end utilizing pumps 1 2 at 779.84 minutes
# Car 204 begins utilizing pumps 1 2 at 779.84 minutes
# Car 385 arrives at 782.73 minutes
# Car 386 arrives at 782.94 minutes
# Car 387 arrives at 783.57 minutes
# Car 204 end utilizing pumps 1 2 at 784.34 minutes
# Car 205 begins utilizing pumps 1 2 at 784.34 minutes
# Car 388 arrives at 785.52 minutes
# Car 205 end utilizing pumps 1 2 at 785.98 minutes
# Car 208 begins utilizing pumps 2 at 785.98 minutes
# Car 206 begins utilizing pumps 1 at 785.98 minutes
# Car 389 arrives at 786.72 minutes
# Car 390 arrives at 788.45 minutes
# Car 391 arrives at 789.42 minutes
# Car 392 arrives at 791.57 minutes
# Car 393 arrives at 791.96 minutes
# Car 394 arrives at 792.07 minutes
# Car 208 end utilizing pumps 2 at 793.47 minutes
# Car 209 begins utilizing pumps 2 at 793.47 minutes
# Car 395 arrives at 794.61 minutes
# Car 396 arrives at 797.6 minutes
# Car 209 end utilizing pumps 2 at 798.59 minutes
# Car 212 begins utilizing pumps 2 at 798.59 minutes
# Car 397 arrives at 798.59 minutes
# Car 206 end utilizing pumps 1 at 800.79 minutes
# Car 207 begins utilizing pumps 1 at 800.79 minutes
# Car 398 arrives at 800.98 minutes
# Car 207 end utilizing pumps 1 at 802.13 minutes
# Car 210 begins utilizing pumps 1 at 802.13 minutes
# Car 399 arrives at 802.66 minutes
# Car 212 end utilizing pumps 2 at 803.88 minutes
# Car 213 begins utilizing pumps 2 at 803.88 minutes
# Car 400 arrives at 804.08 minutes
# Car 401 arrives at 806.56 minutes
# Car 402 arrives at 806.77 minutes
# Car 403 arrives at 806.84 minutes
# Car 404 arrives at 808.52 minutes
# Car 405 arrives at 809.04 minutes
# Car 406 arrives at 810.27 minutes
# Car 407 arrives at 811.54 minutes
# Car 408 arrives at 812.38 minutes
# Car 409 arrives at 812.85 minutes
# Car 410 arrives at 813.1 minutes
# Car 213 end utilizing pumps 2 at 814.91 minutes
# Car 214 begins utilizing pumps 2 at 814.91 minutes
# Car 411 arrives at 816.82 minutes
# Car 210 end utilizing pumps 1 at 817.66 minutes
# Car 211 begins utilizing pumps 1 at 817.66 minutes
# Car 214 end utilizing pumps 2 at 818.97 minutes
# Car 412 arrives at 819.5 minutes
# Car 413 arrives at 820.38 minutes
# Car 414 arrives at 820.42 minutes
# Car 415 arrives at 823.29 minutes
# Car 416 arrives at 824.16 minutes
# Car 417 arrives at 824.42 minutes
# Car 418 arrives at 824.66 minutes
# Car 419 arrives at 824.73 minutes
# Car 420 arrives at 825.5 minutes
# Car 211 end utilizing pumps 1 at 829.07 minutes
# Car 215 begins utilizing pumps 1 at 829.07 minutes
# Car 421 arrives at 831.09 minutes
# Car 422 arrives at 836.2 minutes
# Car 423 arrives at 836.5 minutes
# Car 424 arrives at 837.18 minutes
# Car 425 arrives at 838.77 minutes
# Car 426 arrives at 838.79 minutes
# Car 427 arrives at 839.7 minutes
# Car 428 arrives at 839.71 minutes
# Car 429 arrives at 841.22 minutes
# Car 430 arrives at 843.07 minutes
# Car 431 arrives at 844.27 minutes
# Car 432 arrives at 844.93 minutes
# Car 433 arrives at 845.31 minutes
# Car 434 arrives at 846.15 minutes
# Car 435 arrives at 846.81 minutes
# Car 436 arrives at 847.0 minutes
# Car 437 arrives at 847.41 minutes
# Car 215 end utilizing pumps 1 at 849.5 minutes
# Car 216 begins utilizing pumps 1 at 849.5 minutes
# Car 438 arrives at 853.17 minutes
# Car 439 arrives at 854.67 minutes
# Car 216 end utilizing pumps 1 at 854.96 minutes
# Car 217 begins utilizing pumps 1 2 at 854.96 minutes
# Car 440 arrives at 856.34 minutes
# Car 217 end utilizing pumps 1 2 at 857.99 minutes
# Car 219 begins utilizing pumps 2 at 857.99 minutes
# Car 218 begins utilizing pumps 1 at 857.99 minutes
# Car 441 arrives at 859.45 minutes
# Car 218 end utilizing pumps 1 at 859.93 minutes
# Car 223 begins utilizing pumps 1 at 859.93 minutes
# Car 219 end utilizing pumps 2 at 860.19 minutes
# Car 220 begins utilizing pumps 2 at 860.19 minutes
# Car 442 arrives at 862.25 minutes
# Car 443 arrives at 862.42 minutes
# Car 223 end utilizing pumps 1 at 863.65 minutes
# Car 224 begins utilizing pumps 1 at 863.65 minutes
# Car 444 arrives at 863.68 minutes
# Car 445 arrives at 865.19 minutes
# Car 220 end utilizing pumps 2 at 865.39 minutes
# Car 221 begins utilizing pumps 2 at 865.39 minutes
# Car 224 end utilizing pumps 1 at 865.68 minutes
# Car 446 arrives at 867.19 minutes
# Car 447 arrives at 868.72 minutes
# Car 448 arrives at 870.8 minutes
# Car 221 end utilizing pumps 2 at 872.67 minutes
# Car 222 begins utilizing pumps 2 at 872.67 minutes
# Car 449 arrives at 874.37 minutes
# Car 450 arrives at 875.39 minutes
# Car 222 end utilizing pumps 2 at 877.83 minutes
# Car 225 begins utilizing pumps 1 2 at 877.83 minutes
# Car 451 arrives at 878.87 minutes
# Car 452 arrives at 883.0 minutes
# Car 453 arrives at 883.61 minutes
# Car 454 arrives at 887.26 minutes
# Car 455 arrives at 887.28 minutes
# Car 456 arrives at 887.61 minutes
# Car 457 arrives at 887.76 minutes
# Car 458 arrives at 891.13 minutes
# Car 459 arrives at 891.51 minutes
# Car 460 arrives at 892.66 minutes
# Car 225 end utilizing pumps 1 2 at 893.99 minutes
# Car 226 begins utilizing pumps 2 at 893.99 minutes
# Car 226 end utilizing pumps 2 at 898.72 minutes
# Car 227 begins utilizing pumps 2 at 898.72 minutes
# Car 461 arrives at 899.92 minutes
# Car 462 arrives at 901.22 minutes
# Car 463 arrives at 901.79 minutes
# Car 464 arrives at 902.19 minutes
# Car 227 end utilizing pumps 2 at 902.54 minutes
# Car 228 begins utilizing pumps 1 2 at 902.54 minutes
# Car 465 arrives at 906.88 minutes
# Car 228 end utilizing pumps 1 2 at 909.41 minutes
# Car 229 begins utilizing pumps 1 at 909.41 minutes
# Car 229 end utilizing pumps 1 at 911.95 minutes
# Car 230 begins utilizing pumps 1 at 911.95 minutes
# Car 230 end utilizing pumps 1 at 917.42 minutes
# Car 712 arrives at 1392.78 minutes
# Car 358 end utilizing pumps 1 at 1393.58 minutes
# Car 359 begins utilizing pumps 1 at 1393.58 minutes
# Car 713 arrives at 1397.88 minutes
# Car 359 end utilizing pumps 1 at 1399.68 minutes
# Car 362 begins utilizing pumps 1 at 1399.68 minutes
# Car 362 end utilizing pumps 1 at 1401.49 minutes
# Car 363 begins utilizing pumps 1 at 1401.49 minutes
# Car 714 arrives at 1402.05 minutes
# Car 715 arrives at 1403.0 minutes
# Car 716 arrives at 1407.84 minutes
# Car 717 arrives at 1408.69 minutes
# Car 718 arrives at 1410.28 minutes
# Car 363 end utilizing pumps 1 at 1412.26 minutes
# Car 364 begins utilizing pumps 1 2 at 1412.26 minutes
# Car 719 arrives at 1413.41 minutes
# Car 364 end utilizing pumps 1 2 at 1413.84 minutes
# Car 365 begins utilizing pumps 1 2 at 1413.84 minutes
# Car 365 end utilizing pumps 1 2 at 1415.91 minutes
# Car 366 begins utilizing pumps 1 2 at 1415.91 minutes
# Car 720 arrives at 1420.12 minutes
# Car 366 end utilizing pumps 1 2 at 1420.24 minutes
# Car 368 begins utilizing pumps 2 at 1420.24 minutes
# Car 367 begins utilizing pumps 1 at 1420.24 minutes
# Car 721 arrives at 1420.36 minutes
# Car 368 end utilizing pumps 2 at 1421.89 minutes
# Car 722 arrives at 1422.69 minutes
# Car 723 arrives at 1423.19 minutes
# Car 724 arrives at 1423.32 minutes
# Car 367 end utilizing pumps 1 at 1424.52 minutes
# Car 369 begins utilizing pumps 1 2 at 1424.52 minutes
# Car 725 arrives at 1424.88 minutes
# Car 726 arrives at 1426.16 minutes
# Car 727 arrives at 1427.4 minutes
# Car 728 arrives at 1428.92 minutes
# Car 729 arrives at 1431.7 minutes
# Car 730 arrives at 1433.38 minutes
# Car 731 arrives at 1433.91 minutes
# Car 732 arrives at 1434.81 minutes
# Car 369 end utilizing pumps 1 2 at 1435.17 minutes
# Car 370 begins utilizing pumps 2 at 1435.17 minutes
# Car 733 arrives at 1435.31 minutes
# Car 734 arrives at 1436.89 minutes
# Car 735 arrives at 1437.22 minutes
# Car 370 end utilizing pumps 2 at 1437.26 minutes
# Car 371 begins utilizing pumps 2 at 1437.26 minutes
# Car 736 arrives at 1437.29 minutes
# Car 737 arrives at 1438.67 minutes

# %%
avg_wait_time = np.array([car.wait_time for car in CARS if car.finished]).mean()
total_gallons_sold = sum([pump.gallons_sold for pump in pumps])

for pump in pumps:
    utilization = pump.minutes_utilized / sim_time * len(pumps) 
    print(f'Utilization for pump {pump.name}: {utilization}')
    
for pump in pumps:
    gallons = pump.gallons_sold
    print(f'Gallons sold at pump {pump.name}: {gallons}')
    


print(f'Average wait time (minutes): {avg_wait_time}')
print(f'Total Gallons Sold: {total_gallons_sold}')
# Out:
# Utilization for pump 1: 1.6129849746180722
# Utilization for pump 2: 1.575693176340848
# Gallons sold at pump 1: 3287.508445672349
# Gallons sold at pump 2: 2282.6315303403217
# Average wait time (minutes): 328.155256798708
# Total Gallons Sold: 5570.139976012671
