# %%
import simpy
from scipy.stats import expon
from scipy.stats import norm

# %%
class GasStation():
    
    def __init__(self, env, number_of_pumps):
        
        self.env = env
        
        self.resource = simpy.Resource(self.env, capacity=number_of_pumps)
        
        self.minutes_utilized = 0
        self.gallons_sold = 0

# %%
class Car():

    """
    Attributes:
    -----------
    id (int): A unique id for the car
    gas_required (float): Amount of gallons a car will fill
    lay_time (float): Extra minutes that the car stays at the pump

    """
    
    def __init__(
        self,
        id,
        gas_required,
        lay_time,
        gas_station,
        env
    ):
        self.id = id
        self.gas_required = gas_required
        self.lay_time = lay_time
        self.gas_station = gas_station
        self.env = env
        
        # start the process in the sim
        self.action = self.env.process(self.run())
        
    def run(self):
        
        print(f'Car {self.id} arrives at {self.env.now} minutes')
                
        with self.gas_station.resource.request() as req:
            
            yield req
            
            print(f'Car {self.id} begins utilizing a pump at {self.env.now} minutes')
            
            pump_time = self.gas_required / PUMP_RATE
            
            utilization = max(pump_time, self.lay_time)
            print(utilization)
            
            yield self.env.timeout(utilization)
            
            print(f'Car {self.id} leaves its pump at {self.env.now} minutes')
            
            self.gas_station.minutes_utilized += utilization
            self.gas_station.gallons_sold += self.gas_required

# %%
def scheduler(env):
    
    id = 0
    
    while True:
        
        waiting_time = expon.rvs(loc=0, scale=EXPECTED_WAITING_TIME)
        
        std_norm = norm.rvs()
        gas_required = std_norm * GAS_REQUIRED_STD + GAS_REQUIRED_MEAN
        gas_required = max([0, gas_required])
        
        lay_time = expon.rvs(loc=0, scale=LAY_TIME_MEAN)
        
        yield env.timeout(waiting_time)
        
        Car(
            id=id,
            gas_required=gas_required,
            lay_time=lay_time,
            gas_station=gas_station,
            env=env
        )
        
        id += 1

# %%
PUMP_RATE = 10 # in gallons per minute

# waiting time between cars is exponentially distributed
EXPECTED_WAITING_TIME = 2 # the time between arrivals in minutes

# gas required is normally distributed
GAS_REQUIRED_MEAN = 15 # in gallons
GAS_REQUIRED_STD = 5 # in gallons

# lay time is exponentially distributed
LAY_TIME_MEAN = 5 # in minutes

# %%
env = simpy.Environment()
gas_station = GasStation(env, 1)
env.process(scheduler(env))
env.run(until=100)
# Out:
# Car 0 arrives at 0.856077913588674 minutes
# Car 0 begins utilizing a pump at 0.856077913588674 minutes
# 4.767260077656789
# Car 1 arrives at 2.256424294088653 minutes
# Car 2 arrives at 2.7559740794398295 minutes
# Car 3 arrives at 4.023805766187032 minutes
# Car 0 leaves its pump at 5.623337991245463 minutes
# Car 1 begins utilizing a pump at 5.623337991245463 minutes
# 5.859481175102451
# Car 4 arrives at 6.4342755833567224 minutes
# Car 5 arrives at 9.923108257053393 minutes
# Car 6 arrives at 10.747416139445606 minutes
# Car 7 arrives at 11.300721479420899 minutes
# Car 1 leaves its pump at 11.482819166347914 minutes
# Car 2 begins utilizing a pump at 11.482819166347914 minutes
# 3.7539232327868444
# Car 8 arrives at 11.989195699897635 minutes
# Car 9 arrives at 13.421068895087597 minutes
# Car 10 arrives at 14.308675281547686 minutes
# Car 11 arrives at 14.508388967384718 minutes
# Car 2 leaves its pump at 15.236742399134759 minutes
# Car 3 begins utilizing a pump at 15.236742399134759 minutes
# 0.6130223025364467
# Car 3 leaves its pump at 15.849764701671205 minutes
# Car 4 begins utilizing a pump at 15.849764701671205 minutes
# 3.77515131969194
# Car 12 arrives at 16.123037324795312 minutes
# Car 13 arrives at 17.407188216366425 minutes
# Car 14 arrives at 17.471716702474147 minutes
# Car 15 arrives at 18.78461560645516 minutes
# Car 4 leaves its pump at 19.624916021363145 minutes
# Car 5 begins utilizing a pump at 19.624916021363145 minutes
# 1.0579176055126915
# Car 5 leaves its pump at 20.682833626875837 minutes
# Car 6 begins utilizing a pump at 20.682833626875837 minutes
# 1.9194339798082294
# Car 16 arrives at 20.94250374358426 minutes
# Car 17 arrives at 22.500996354326908 minutes
# Car 6 leaves its pump at 22.602267606684066 minutes
# Car 7 begins utilizing a pump at 22.602267606684066 minutes
# 8.26755196761534
# Car 18 arrives at 22.630058593600694 minutes
# Car 19 arrives at 23.322792649677083 minutes
# Car 20 arrives at 23.4262274281325 minutes
# Car 21 arrives at 23.755613834913973 minutes
# Car 22 arrives at 24.382806009070002 minutes
# Car 23 arrives at 27.24057946518142 minutes
# Car 24 arrives at 27.47641655804967 minutes
# Car 25 arrives at 29.190255229666153 minutes
# Car 26 arrives at 30.074550016542382 minutes
# Car 7 leaves its pump at 30.869819574299406 minutes
# Car 8 begins utilizing a pump at 30.869819574299406 minutes
# 5.127904199460148
# Car 27 arrives at 32.15075275762648 minutes
# Car 8 leaves its pump at 35.99772377375955 minutes
# Car 9 begins utilizing a pump at 35.99772377375955 minutes
# 3.4760760224349676
# Car 28 arrives at 39.12323590061098 minutes
# Car 9 leaves its pump at 39.47379979619452 minutes
# Car 10 begins utilizing a pump at 39.47379979619452 minutes
# 1.1342230225309542
# Car 10 leaves its pump at 40.60802281872547 minutes
# Car 11 begins utilizing a pump at 40.60802281872547 minutes
# 2.206373555049077
# Car 11 leaves its pump at 42.81439637377455 minutes
# Car 12 begins utilizing a pump at 42.81439637377455 minutes
# 2.088206327287945
# Car 29 arrives at 44.45130082320721 minutes
# Car 30 arrives at 44.60293585479746 minutes
# Car 12 leaves its pump at 44.90260270106249 minutes
# Car 13 begins utilizing a pump at 44.90260270106249 minutes
# 3.0291089368316926
# Car 31 arrives at 46.273398083620314 minutes
# Car 13 leaves its pump at 47.93171163789418 minutes
# Car 14 begins utilizing a pump at 47.93171163789418 minutes
# 1.0323505672226947
# Car 14 leaves its pump at 48.964062205116875 minutes
# Car 15 begins utilizing a pump at 48.964062205116875 minutes
# 7.649514330537382
# Car 32 arrives at 50.275473221965704 minutes
# Car 33 arrives at 53.39006134420326 minutes
# Car 34 arrives at 56.41869024690223 minutes
# Car 15 leaves its pump at 56.61357653565426 minutes
# Car 16 begins utilizing a pump at 56.61357653565426 minutes
# 4.937591293639344
# Car 16 leaves its pump at 61.551167829293604 minutes
# Car 17 begins utilizing a pump at 61.551167829293604 minutes
# 0.9594281211641376
# Car 35 arrives at 61.69628299087701 minutes
# Car 17 leaves its pump at 62.51059595045774 minutes
# Car 18 begins utilizing a pump at 62.51059595045774 minutes
# 7.901952023930747
# Car 36 arrives at 62.63385691079016 minutes
# Car 37 arrives at 63.10839395573612 minutes
# Car 38 arrives at 64.19950561271708 minutes
# Car 39 arrives at 64.59178161909544 minutes
# Car 40 arrives at 68.07301297025099 minutes
# Car 41 arrives at 68.43902753330318 minutes
# Car 18 leaves its pump at 70.41254797438849 minutes
# Car 19 begins utilizing a pump at 70.41254797438849 minutes
# 2.0455929195084344
# Car 42 arrives at 70.43654143892023 minutes
# Car 43 arrives at 70.55815283156109 minutes
# Car 19 leaves its pump at 72.45814089389692 minutes
# Car 20 begins utilizing a pump at 72.45814089389692 minutes
# 2.4114640576265876
# Car 44 arrives at 73.21374252405379 minutes
# Car 45 arrives at 73.2282223914217 minutes
# Car 46 arrives at 74.12689684914882 minutes
# Car 47 arrives at 74.28645952138696 minutes
# Car 20 leaves its pump at 74.86960495152351 minutes
# Car 21 begins utilizing a pump at 74.86960495152351 minutes
# 12.252049550157626
# Car 48 arrives at 74.95524512103749 minutes
# Car 49 arrives at 84.44355169549793 minutes
# Car 50 arrives at 86.87566061504424 minutes
# Car 21 leaves its pump at 87.12165450168114 minutes
# Car 22 begins utilizing a pump at 87.12165450168114 minutes
# 5.54890690041876
# Car 51 arrives at 89.69183980153554 minutes
# Car 52 arrives at 91.0302581344211 minutes
# Car 22 leaves its pump at 92.67056140209989 minutes
# Car 23 begins utilizing a pump at 92.67056140209989 minutes
# 5.5070147062488
# Car 53 arrives at 93.45213268300247 minutes
# Car 54 arrives at 94.09291525238108 minutes
# Car 55 arrives at 94.4289770680006 minutes
# Car 56 arrives at 94.45209386542948 minutes
# Car 57 arrives at 94.6537229311863 minutes
# Car 58 arrives at 94.76856568581543 minutes
# Car 59 arrives at 94.86743312580381 minutes
# Car 60 arrives at 96.23043886096711 minutes
# Car 23 leaves its pump at 98.17757610834869 minutes
# Car 24 begins utilizing a pump at 98.17757610834869 minutes
# 9.536563738629798
# Car 61 arrives at 98.18364763432537 minutes
# Car 62 arrives at 98.71683871184419 minutes
# Car 63 arrives at 99.42855988565167 minutes
